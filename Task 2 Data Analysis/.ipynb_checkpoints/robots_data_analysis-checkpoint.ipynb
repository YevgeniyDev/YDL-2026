# %%
import pandas as pd

# %%
df = pd.read_csv('global_humanoid_robotics_intelligence_2026.csv')

# %%
# Number of rows and columns
print('Shape (rows, columns):', df.shape)
print('Rows:', df.shape[0])
print('Columns:', df.shape[1])
# Out:
# Shape (rows, columns): (52, 68)
# Rows: 52
# Columns: 68

# %%
df.head()
# Out:
#        robot_uid        robot_name           company country country_iso  \
# 0  HRBT-9776433F     Optimus Gen 2             Tesla     USA          US
# 1  HRBT-AE204127  Atlas (Electric)   Boston Dynamics     USA          US
# 2  HRBT-6F112F40         Figure 02         Figure Ai     USA          US
# 3  HRBT-4C9723C9          Digit V4  Agility Robotics     USA          US
# 4  HRBT-6175E4F1      Apollo Gen 1         Apptronik     USA          US
#
#        continent    hq_city  founded_year  company_age_years  publicly_traded  \
# 0  North America     Austin          2021                  5             True
# 1  North America    Waltham          1992                 34            False
# 2  North America  Sunnyvale          2022                  4            False
# 3  North America  Corvallis          2015                 11            False
# 4  North America     Austin          2016                 10            False
#
#    ... open_source  api_available  outlier_flag  row_completeness_pct  \
# 0  ...       False          False         False                 87.50
# 1  ...       False          False         False                 91.07
# 2  ...       False          False         False                 94.64
# 3  ...       False           True         False                 96.43
# 4  ...       False          False         False                 87.50
#
#    verification_status                                data_source  \
# 0             Verified          Tesla AI Day 2024, Press Releases
# 1             Verified                  Boston Dynamics Blog 2024
# 2             Verified  Figure AI Press Releases, TechCrunch 2024
# 3             Verified  Agility Robotics 2024, Amazon Partnership
# 4             Verified                       Apptronik Press 2023
#
#    dataset_version             build_timestamp  data_curated_year  \
# 0           v1.0.0  2026-05-24T09:47:19.739145               2026
# 1           v1.0.0  2026-05-24T09:47:19.739145               2026
# 2           v1.0.0  2026-05-24T09:47:19.739145               2026
# 3           v1.0.0  2026-05-24T09:47:19.739145               2026
# 4           v1.0.0  2026-05-24T09:47:19.739145               2026
#
#    valuation_is_estimated
# 0                   False
# 1                   False
# 2                   False
# 3                    True
# 4                    True
#
# [5 rows x 68 columns]

# %%
# List of columns
df.columns.tolist()
# Out:
# ['robot_uid',
#  'robot_name',
#  'company',
#  'country',
#  'country_iso',
#  'continent',
#  'hq_city',
#  'founded_year',
#  'company_age_years',
#  'publicly_traded',
#  'ticker',
#  'ipo_year',
#  'num_employees_company',
#  'robot_release_year',
#  'robot_age_years',
#  'height_cm',
#  'weight_kg',
#  'weight_class',
#  'dof',
#  'hands_dof',
#  'biped',
#  'wheeled_option',
#  'max_speed_kmh',
#  'walking_speed_kmh',
#  'speed_ratio',
#  'battery_life_hrs',
#  'max_payload_kg',
#  'power_efficiency',
#  'camera_count',
#  'lidar',
#  'force_torque_sensors',
#  'tactile_sensors',
#  'sensor_richness_score',
#  'dexterity_index',
#  'onboard_compute',
#  'ai_framework',
#  'llm_integrated',
#  'sim_to_real',
#  'primary_use_case',
#  'secondary_use_case',
#  'deployment_stage',
#  'target_market',
#  'market_segment_code',
#  'units_deployed',
#  'unit_cost_usd_k',
#  'total_funding_usd_m',
#  'latest_valuation_usd_b',
#  'latest_funding_round',
#  'funding_round_year',
#  'key_investors',
#  'ceo',
#  'funding_per_employee_k',
#  'ai_maturity_score',
#  'innovation_score',
#  'commercial_readiness_idx',
#  'openness_score',
#  'time_to_market_years',
#  'geopolitical_tier',
#  'open_source',
#  'api_available',
#  'outlier_flag',
#  'row_completeness_pct',
#  'verification_status',
#  'data_source',
#  'dataset_version',
#  'build_timestamp',
#  'data_curated_year',
#  'valuation_is_estimated']

# %%
# Data types per column
df.dtypes
# Out:
# robot_uid                 object
# robot_name                object
# company                   object
# country                   object
# country_iso               object
#                            ...
# data_source               object
# dataset_version           object
# build_timestamp           object
# data_curated_year          int64
# valuation_is_estimated      bool
# Length: 68, dtype: object

# %%
# info(): dtypes + non-null counts
df.info()

# describe(): statistics for numeric columns
display(df.describe())

# Missing values per column (only where any), sorted
missing = df.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
display(pd.DataFrame({
    'n_missing': missing,
    'pct_missing': (missing / len(df) * 100).round(1)
}))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 68 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   robot_uid                 52 non-null     object
#  1   robot_name                52 non-null     object
#  2   company                   52 non-null     object
#  3   country                   52 non-null     object
#  4   country_iso               52 non-null     object
#  5   continent                 52 non-null     object
#  6   hq_city                   52 non-null     object
#  7   founded_year              52 non-null     int64
#  8   company_age_years         52 non-null     int64
#  9   publicly_traded           52 non-null     bool
#  10  ticker                    8 non-null      object
#  11  ipo_year                  8 non-null      float64
#  12  num_employees_company     52 non-null     int64
#  13  robot_release_year        52 non-null     int64
#  14  robot_age_years           52 non-null     int64
#  15  height_cm                 52 non-null     float64
#  16  weight_kg                 49 non-null     float64
#  17  weight_class              52 non-null     object
#  18  dof                       51 non-null     float64
#  19  hands_dof                 52 non-null     float64
#  20  biped                     52 non-null     bool
#  21  wheeled_option            52 non-null     bool
#  22  max_speed_kmh             39 non-null     float64
#  23  walking_speed_kmh         39 non-null     float64
#  24  speed_ratio               37 non-null     float64
#  25  battery_life_hrs          37 non-null     float64
#  26  max_payload_kg            36 non-null     float64
#  27  power_efficiency          33 non-null     float64
#  28  camera_count              52 non-null     float64
#  29  lidar                     52 non-null     bool
#  30  force_torque_sensors      52 non-null     bool
#  31  tactile_sensors           52 non-null     bool
#  32  sensor_richness_score     52 non-null     float64
#  33  dexterity_index           51 non-null     float64
#  34  onboard_compute           52 non-null     object
#  35  ai_framework              52 non-null     object
#  36  llm_integrated            52 non-null     bool
#  37  sim_to_real               52 non-null     bool
#  38  primary_use_case          52 non-null     object
#  39  secondary_use_case        52 non-null     object
#  40  deployment_stage          52 non-null     object
#  41  target_market             52 non-null     object
#  42  market_segment_code       52 non-null     object
#  43  units_deployed            52 non-null     float64
#  44  unit_cost_usd_k           23 non-null     float64
#  45  total_funding_usd_m       22 non-null     float64
#  46  latest_valuation_usd_b    22 non-null     float64
#  47  latest_funding_round      52 non-null     object
#  48  funding_round_year        21 non-null     float64
#  49  key_investors             52 non-null     object
#  50  ceo                       45 non-null     object
#  51  funding_per_employee_k    22 non-null     float64
#  52  ai_maturity_score         52 non-null     int64
#  53  innovation_score          52 non-null     float64
#  54  commercial_readiness_idx  52 non-null     float64
#  55  openness_score            52 non-null     float64
#  56  time_to_market_years      52 non-null     int64
#  57  geopolitical_tier         52 non-null     object
#  58  open_source               52 non-null     bool
#  59  api_available             52 non-null     bool
#  60  outlier_flag              52 non-null     bool
#  61  row_completeness_pct      52 non-null     float64
#  62  verification_status       52 non-null     object
#  63  data_source               52 non-null     object
#  64  dataset_version           52 non-null     object
#  65  build_timestamp           52 non-null     object
#  66  data_curated_year         52 non-null     int64
#  67  valuation_is_estimated    52 non-null     bool
# dtypes: bool(12), float64(24), int64(8), object(24)
# memory usage: 23.5+ KB
#        founded_year  company_age_years     ipo_year  num_employees_company  \
# count     52.000000          52.000000     8.000000              52.000000
# mean    1998.230769          27.769231  2000.750000           28314.884615
# std       44.646593          44.646593    11.259916          103224.953868
# min     1825.000000           2.000000  1984.000000              20.000000
# 25%     2004.000000           5.000000  1994.000000              95.000000
# 50%     2015.500000          10.500000  1998.000000             300.000000
# 75%     2021.000000          22.000000  2010.000000            3500.000000
# max     2024.000000         201.000000  2018.000000          700000.000000
#
#        robot_release_year  robot_age_years   height_cm    weight_kg  \
# count           52.000000        52.000000   52.000000    49.000000
# mean          2020.788462         5.211538  166.788462   130.918367
# std              5.191760         5.191760   48.404074   492.026405
# min           2000.000000         0.000000   58.000000     3.500000
# 25%           2018.000000         2.000000  160.000000    47.000000
# 50%           2023.000000         3.000000  170.000000    57.000000
# 75%           2024.000000         8.000000  175.500000    76.000000
# max           2026.000000        26.000000  450.000000  3500.000000
#
#              dof  hands_dof  ...  latest_valuation_usd_b  funding_round_year  \
# count  51.000000  52.000000  ...               22.000000           21.000000
# mean   34.666667   8.730769  ...                2.397727         2023.428571
# std    11.318422   4.097419  ...                8.363010            1.164965
# min    12.000000   0.000000  ...                0.030000         2021.000000
# 25%    26.000000   6.000000  ...                0.075000         2023.000000
# 50%    34.000000   8.000000  ...                0.245000         2024.000000
# 75%    42.000000  12.000000  ...                0.712500         2024.000000
# max    67.000000  16.000000  ...               39.500000         2025.000000
#
#        funding_per_employee_k  ai_maturity_score  innovation_score  \
# count               22.000000          52.000000         52.000000
# mean               765.527273           2.923077         48.475577
# std                738.065726           1.202060         21.600780
# min                100.000000           0.000000         12.460000
# 25%                333.330000           2.000000         31.600000
# 50%                501.665000           3.000000         46.435000
# 75%                773.437500           4.000000         62.687500
# max               2550.000000           5.000000         86.780000
#
#        commercial_readiness_idx  openness_score  time_to_market_years  \
# count                 52.000000       52.000000             52.000000
# mean                  74.519231       28.846154             22.557692
# std                   23.540945       41.238372             42.092528
# min                   15.000000        0.000000              1.000000
# 25%                   58.750000        0.000000              3.000000
# 50%                   75.000000        0.000000              7.000000
# 75%                  100.000000       50.000000             14.000000
# max                  100.000000      100.000000            193.000000
#
#        row_completeness_pct  data_curated_year
# count             52.000000               52.0
# mean              82.931923             2026.0
# std                6.591442                0.0
# min               69.640000             2026.0
# 25%               78.570000             2026.0
# 50%               82.140000             2026.0
# 75%               87.500000             2026.0
# max               96.430000             2026.0
#
# [8 rows x 32 columns]
#                         n_missing  pct_missing
# ticker                         44         84.6
# ipo_year                       44         84.6
# funding_round_year             31         59.6
# latest_valuation_usd_b         30         57.7
# total_funding_usd_m            30         57.7
# funding_per_employee_k         30         57.7
# unit_cost_usd_k                29         55.8
# power_efficiency               19         36.5
# max_payload_kg                 16         30.8
# speed_ratio                    15         28.8
# battery_life_hrs               15         28.8
# walking_speed_kmh              13         25.0
# max_speed_kmh                  13         25.0
# ceo                             7         13.5
# weight_kg                       3          5.8
# dexterity_index                 1          1.9
# dof                             1          1.9

# %% [markdown]
# ### Answer
#
# **Missing values** (top of 17 columns with gaps, out of 52 rows):
#
# | Column | Missing |
# |---|---|
# | `ticker`, `ipo_year` | 85% |
# | `funding_round_year` | 60% |
# | `total_funding_usd_m`, `latest_valuation_usd_b`, `funding_per_employee_k` | 58% |
# | `unit_cost_usd_k` | 56% |
# | `power_efficiency`, `max_payload_kg`, speeds, `battery_life_hrs` | 25–37% |
#
# → Gaps are mostly **financial fields** — private startups don't report them.
#
# **Wrong dtypes:**
# - `build_timestamp` → text, should be **datetime**
# - `ipo_year`, `funding_round_year` → float, should be **Int** (float only because of NaN)
# - `dof`, `hands_dof`, `camera_count` → float, conceptually **integers**

# %% [markdown]
# ### Prompt
# Show only robots made in china and which have more than 12 DOF

# %%
# Robots from China with more than 12 degrees of freedom (DOF)
china_high_dof = df[(df['country'] == 'China') & (df['dof'] > 12)]

print('Robots found:', len(china_high_dof))
china_high_dof[['robot_name', 'company', 'hq_city', 'dof', 'primary_use_case']] \
    .sort_values('dof', ascending=False) \
    .reset_index(drop=True)
# Out:
# Robots found: 15
#         robot_name                                   company   hq_city   dof  \
# 0     Fourier Gr-2                      Fourier Intelligence  Shanghai  53.0
# 1       Unitree G1                          Unitree Robotics  Hangzhou  43.0
# 2         Tiangong  Beijing Humanoid Robot Innovation Center   Beijing  42.0
# 3         Walker X                           Ubtech Robotics  Shenzhen  41.0
# 4     Fourier Gr-1                      Fourier Intelligence  Shanghai  40.0
# 5        Aimbot S1                                    Agibot  Shanghai  40.0
# 6    Bd-1 Humanoid                              Byd Robotics  Shenzhen  40.0
# 7        Kepler K1                           Kepler Robotics  Shanghai  40.0
# 8            Kuavo                             Leju Robotics  Shenzhen  38.0
# 9        Galbot G1                                    Galbot   Beijing  36.0
# 10       Limx Cl-1                             Limx Dynamics  Shenzhen  30.0
# 11  Unitree H1 Pro                          Unitree Robotics  Hangzhou  27.0
# 12      Booster T1                          Booster Robotics   Beijing  22.0
# 13        Cyberone                                    Xiaomi   Beijing  21.0
# 14      Unitree H1                          Unitree Robotics  Hangzhou  19.0
#
#        primary_use_case
# 0         Manufacturing
# 1              Research
# 2              Research
# 3               Service
# 4        Rehabilitation
# 5         Manufacturing
# 6   Automotive Assembly
# 7         Manufacturing
# 8              Research
# 9                Retail
# 10             Research
# 11             Research
# 12           Industrial
# 13            Companion
# 14             Research

# %% [markdown]
# ### Prompt
# show how many robots made in each country and provide companies names too

# %%
# Number of robots per country + list of companies
by_country = df.groupby('country').agg(
    n_robots=('robot_name', 'size'),
    n_companies=('company', 'nunique'),
    companies=('company', lambda s: ', '.join(sorted(s.unique())))
).sort_values('n_robots', ascending=False)

pd.set_option('display.max_colwidth', None)
by_country
# Out:
#              n_robots  n_companies  \
# country
# China              16           13
# USA                12            9
# Japan               6            5
# France              5            4
# Canada              2            2
# Germany             2            2
# Norway              2            2
# Spain               2            1
# Iran                1            1
# Israel              1            1
# Italy               1            1
# South Korea         1            1
# UK                  1            1
#
#                                                                                                                                                                                                                       companies
# country
# China        Agibot, Astribot, Beijing Humanoid Robot Innovation Center, Booster Robotics, Byd Robotics, Fourier Intelligence, Galbot, Kepler Robotics, Leju Robotics, Limx Dynamics, Ubtech Robotics, Unitree Robotics, Xiaomi
# USA                                                                                        Agility Robotics, Apptronik, Boston Dynamics, Figure Ai, Nasa / General Motors, Nasa / Jsc, Neural Interfaces (Tri), Proxi Ai, Tesla
# Japan                                                                                                                                              Aist, Aist / Kawada Industries, Honda, Softbank Robotics, Tsubame Industries
# France                                                                                                                                                 Enchanted Tools, Inria / Flowers Lab, Pollen Robotics, Softbank Robotics
# Canada                                                                                                                                                                                     Exosapien Technologies, Sanctuary Ai
# Germany                                                                                                                                                                 Dlr German Aerospace, Karlsruhe Institute Of Technology
# Norway                                                                                                                                                                                         1X Technologies, Halodi Robotics
# Spain                                                                                                                                                                                                              Pal Robotics
# Iran                                                                                                                                                                                                       University Of Tehran
# Israel                                                                                                                                                                                                          Mentee Robotics
# Italy                                                                                                                                                                                           Istituto Italiano Di Tecnologia
# South Korea                                                                                                                                                                                                               Kaist
# UK                                                                                                                                                                                                              Engineered Arts

# %%
2 pie chart showing the data above

# %% [markdown]
# ### Prompt
# Show me the average robot cost in each country

# %%
# Average robot cost (unit_cost_usd_k, thousand $) per country
avg_cost = df.groupby('country')['unit_cost_usd_k'].agg(
    avg_cost_usd_k='mean',
    n_with_price='count'      # count ignores NaN
).round(1).sort_values('avg_cost_usd_k', ascending=False)

print('Robots with a listed price:', df['unit_cost_usd_k'].notna().sum(), 'of', len(df))
avg_cost
# Out:
# Robots with a listed price: 23 of 52
#              avg_cost_usd_k  n_with_price
# country
# Japan                1387.5             4
# USA                   716.4             7
# Spain                 425.0             2
# Italy                 270.0             1
# China                  61.8             6
# France                 28.7             3
# Canada                  NaN             0
# Germany                 NaN             0
# Iran                    NaN             0
# Israel                  NaN             0
# Norway                  NaN             0
# South Korea             NaN             0
# UK                      NaN             0

# %% [markdown]
# ### Prompt
# Show me the difference in Japan's Robots' capabilities and China's

# %%
# Compare capabilities of Japan vs China robots (mean per country)
caps = [
    'dof', 'hands_dof', 'height_cm', 'weight_kg',
    'max_speed_kmh', 'walking_speed_kmh', 'max_payload_kg', 'battery_life_hrs',
    'camera_count', 'sensor_richness_score', 'dexterity_index',
    'ai_maturity_score', 'innovation_score', 'commercial_readiness_idx',
    'robot_age_years'
]

jc = df[df['country'].isin(['Japan', 'China'])]
print('Robot counts:', jc['country'].value_counts().to_dict())

comparison = jc.groupby('country')[caps].mean().round(2).T
comparison['China_minus_Japan'] = (comparison['China'] - comparison['Japan']).round(2)
display(comparison)

# Medians too (weight/height are skewed by the Archax mech = 3500 kg in Japan)
display(jc.groupby('country')[['height_cm', 'weight_kg']].median().round(1))

# Share of robots with an integrated LLM
display(jc.groupby('country')['llm_integrated'].mean().round(2))
# Out:
# Robot counts: {'China': 16, 'Japan': 6}
# country                    China   Japan  China_minus_Japan
# dof                        35.47   31.67               3.80
# hands_dof                  10.12    4.17               5.95
# height_cm                 168.69  192.50             -23.81
# weight_kg                  55.33  625.33            -570.00
# max_speed_kmh               6.87    5.00               1.87
# walking_speed_kmh           4.61    1.85               2.76
# max_payload_kg             13.53     NaN                NaN
# battery_life_hrs            3.23    6.50              -3.27
# camera_count                4.50    2.67               1.83
# sensor_richness_score       3.06    1.17               1.89
# dexterity_index            52.94   47.26               5.68
# ai_maturity_score           3.12    1.33               1.79
# innovation_score           59.28   21.65              37.63
# commercial_readiness_idx   79.38   45.83              33.55
# robot_age_years             2.25   12.67             -10.42
#          height_cm  weight_kg
# country
# China        170.0       52.0
# Japan        140.5       46.5
# country
# China    0.5
# Japan    0.0
# Name: llm_integrated, dtype: float64

# %% [markdown]
# ### Prompt
# is there a correlation between speed, weight and the cost?

# %%
# Correlation between speed, weight and cost
cols = ['max_speed_kmh', 'weight_kg', 'unit_cost_usd_k']

print('Non-null counts per column:')
print(df[cols].notna().sum().to_string())
print('\nRows with all three present:', df[cols].dropna().shape[0])

print('\nPearson (linear):')
display(df[cols].corr().round(3))

print('Spearman (rank / monotonic, robust to outliers):')
display(df[cols].corr(method='spearman').round(3))
# Out:
# Non-null counts per column:
# max_speed_kmh      39
# weight_kg          49
# unit_cost_usd_k    23
#
# Rows with all three present: 17
#
# Pearson (linear):
#                  max_speed_kmh  weight_kg  unit_cost_usd_k
# max_speed_kmh            1.000      0.087            0.193
# weight_kg                0.087      1.000            0.593
# unit_cost_usd_k          0.193      0.593            1.000
# Spearman (rank / monotonic, robust to outliers):
#                  max_speed_kmh  weight_kg  unit_cost_usd_k
# max_speed_kmh            1.000      0.027            0.073
# weight_kg                0.027      1.000            0.743
# unit_cost_usd_k          0.073      0.743            1.000

# %% [markdown]
# ### Answer
#
# Only 17 robots have all three values, so this is suggestive.
#
# | Pair | Pearson | Spearman | Result |
# |---|---|---|---|
# | weight ↔ cost | 0.59 | **0.74** | **Yes** — heavier = pricier |
# | speed ↔ cost | 0.19 | 0.07 | No |
# | speed ↔ weight | 0.09 | 0.03 | No |
#
# → **Weight drives cost; speed relates to neither.**

# %% [markdown]
# ### Prompt
# show me robots with ai feature and show the years these robots were made

# %%
# Robots with an AI feature = integrated LLM (llm_integrated == True), with release year
ai_robots = df[df['llm_integrated'] == True]

print('Robots with an LLM/AI feature:', len(ai_robots), 'of', len(df))

display(
    ai_robots[['robot_name', 'company', 'country', 'robot_release_year', 'ai_framework']]
    .sort_values('robot_release_year')
    .reset_index(drop=True)
)

# How many such robots were released per year
print('Count by release year:')
display(ai_robots['robot_release_year'].value_counts().sort_index())
# Out:
# Robots with an LLM/AI feature: 20 of 52
#                     robot_name               company country  \
# 0                        Ameca       Engineered Arts      UK
# 1                     Walker X       Ubtech Robotics   China
# 2   Spot Arm (Humanoid Config)       Boston Dynamics     USA
# 3                      Phoenix          Sanctuary Ai  Canada
# 4                Optimus Gen 2                 Tesla     USA
# 5                 Fourier Gr-2  Fourier Intelligence   China
# 6                    Robot One       Enchanted Tools  France
# 7                     Reachy 2       Pollen Robotics  France
# 8                    Galbot G1                Galbot   China
# 9          Enchanted Robot One       Enchanted Tools  France
# 10                 Astribot S1              Astribot   China
# 11                   Aimbot S1                Agibot   China
# 12                    Neo Beta       1X Technologies  Norway
# 13                   Figure 02             Figure Ai     USA
# 14               Bd-1 Humanoid          Byd Robotics   China
# 15                   Kepler K1       Kepler Robotics   China
# 16              Unitree H1 Pro      Unitree Robotics   China
# 17                   Figure 03             Figure Ai     USA
# 18                Naviai Alpha              Proxi Ai     USA
# 19               Optimus Gen 3                 Tesla     USA
#
#     robot_release_year            ai_framework
# 0                 2021      Gpt-4 + Tritium Os
# 1                 2021               Ubtech Ai
# 2                 2021                Spot Sdk
# 3                 2023   Carbon (Agi Platform)
# 4                 2024        Tesla Neural Net
# 5                 2024  Fourier Gr Platform V2
# 6                 2024        Mirokai Platform
# 7                 2024                    Ros2
# 8                 2024              Galbot Vla
# 9                 2024        Mirokai Platform
# 10                2024           Vla Dexterous
# 11                2024      Agibot World Model
# 12                2024          World Model Rl
# 13                2024             Helix (Vla)
# 14                2025                  Byd Ai
# 15                2025              Kepler Vla
# 16                2025               Ros2 + Rl
# 17                2025            Helix Vla V2
# 18                2026           Sovereign Llm
# 19                2026     Tesla Neural Net V3
# Count by release year:
# robot_release_year
# 2021     3
# 2023     1
# 2024    10
# 2025     4
# 2026     2
# Name: count, dtype: int64

# %% [markdown]
# ### Answer
#
# "AI feature" = integrated LLM (`llm_integrated`). **20 of 52 robots**, all released **2021+**.
#
# **By year:** 2021 → 3 · 2023 → 1 · **2024 → 10** · 2025 → 4 · 2026 → 2
#
# → LLM robots spike in **2024** (post-GPT wave); none exist before 2021. Mostly **China + USA** (Tesla Optimus, Figure 02/03, Unitree H1 Pro, and several Chinese VLA platforms). Full list in the table above.

# %% [markdown]
# ### Prompt
# Find 3 hardly predictable correlations within this dataset

# %%
# Hunt for surprising (non-obvious) correlations.
# We report BOTH Pearson and Spearman: agreement = robust; disagreement = outlier artifact.
import itertools

# All numeric columns considered for the comparison (drop id-like / bookkeeping ones)
num = df.select_dtypes(include=['float64', 'int64']).drop(
    columns=['data_curated_year', 'row_completeness_pct'], errors='ignore')
print('Columns compared (%d):' % num.shape[1])
print(list(num.columns))

def corr_pair(a, b):
    s = df[[a, b]].dropna()
    return pd.Series({
        'pearson': round(s[a].corr(s[b]), 3),
        'spearman': round(s[a].corr(s[b], method='spearman'), 3),
        'n': len(s)
    })

# --- Full pairwise scan over every numeric column pair (n >= 15) ---
scan = []
for a, b in itertools.combinations(num.columns, 2):
    cp = corr_pair(a, b)
    if cp['n'] >= 15 and pd.notna(cp['pearson']):
        scan.append({'pair': f'{a} ↔ {b}', **cp.to_dict(), 'abs_pearson': abs(cp['pearson'])})

scan = pd.DataFrame(scan).sort_values('abs_pearson', ascending=False)

# Drop the obvious / tautological pairs so only non-obvious ones remain
trivial = [
    'robot_release_year ↔ robot_age_years', 'founded_year ↔ company_age_years',
    'dof ↔ dexterity_index', 'company_age_years ↔ time_to_market_years',
    'founded_year ↔ time_to_market_years', 'max_speed_kmh ↔ walking_speed_kmh',
    'height_cm ↔ weight_kg', 'total_funding_usd_m ↔ latest_valuation_usd_b',
    'units_deployed ↔ latest_valuation_usd_b', 'units_deployed ↔ total_funding_usd_m',
    'ai_maturity_score ↔ commercial_readiness_idx',
]
non_obvious = scan[~scan['pair'].isin(trivial)]
print('\nTop non-obvious correlations:')
display(non_obvious.head(15).reset_index(drop=True))

# --- The three non-obvious correlations chosen (robust under both metrics) ---
candidates = [
    ('max_payload_kg', 'power_efficiency'),     # heavier payload -> MORE efficient
    ('walking_speed_kmh', 'max_payload_kg'),    # faster walkers also carry more
    ('company_age_years', 'unit_cost_usd_k'),   # older companies -> pricier robots
    ('speed_ratio', 'unit_cost_usd_k'),         # looks strong but is a trap (see answer)
]
result = pd.DataFrame({f'{a} ↔ {b}': corr_pair(a, b) for a, b in candidates}).T
print('\nChosen pairs:')
result
# Out:
# Columns compared (30):
# ['founded_year', 'company_age_years', 'ipo_year', 'num_employees_company', 'robot_release_year', 'robot_age_years', 'height_cm', 'weight_kg', 'dof', 'hands_dof', 'max_speed_kmh', 'walking_speed_kmh', 'speed_ratio', 'battery_life_hrs', 'max_payload_kg', 'power_efficiency', 'camera_count', 'sensor_richness_score', 'dexterity_index', 'units_deployed', 'unit_cost_usd_k', 'total_funding_usd_m', 'latest_valuation_usd_b', 'funding_round_year', 'funding_per_employee_k', 'ai_maturity_score', 'innovation_score', 'commercial_readiness_idx', 'openness_score', 'time_to_market_years']
#
# Top non-obvious correlations:
#                                            pair  pearson  spearman     n  \
# 0                 speed_ratio ↔ unit_cost_usd_k   -0.897     0.106  15.0
# 1      sensor_richness_score ↔ innovation_score    0.862     0.856  52.0
# 2             max_payload_kg ↔ power_efficiency    0.835     0.886  33.0
# 3       robot_release_year ↔ funding_round_year    0.773     0.675  21.0
# 4          robot_age_years ↔ funding_round_year   -0.773    -0.675  21.0
# 5             hands_dof ↔ sensor_richness_score    0.708     0.729  52.0
# 6                  hands_dof ↔ innovation_score    0.678     0.674  52.0
# 7          walking_speed_kmh ↔ power_efficiency    0.673     0.499  32.0
# 8          camera_count ↔ sensor_richness_score    0.659     0.702  52.0
# 9                founded_year ↔ unit_cost_usd_k   -0.658    -0.430  23.0
# 10          company_age_years ↔ unit_cost_usd_k    0.658     0.430  23.0
# 11  num_employees_company ↔ total_funding_usd_m    0.655     0.752  22.0
# 12           camera_count ↔ total_funding_usd_m    0.644     0.606  22.0
# 13             max_speed_kmh ↔ power_efficiency    0.637     0.435  31.0
# 14              camera_count ↔ innovation_score    0.636     0.638  52.0
#
#     abs_pearson
# 0         0.897
# 1         0.862
# 2         0.835
# 3         0.773
# 4         0.773
# 5         0.708
# 6         0.678
# 7         0.673
# 8         0.659
# 9         0.658
# 10        0.658
# 11        0.655
# 12        0.644
# 13        0.637
# 14        0.636
# Chosen pairs:
#                                      pearson  spearman     n
# max_payload_kg ↔ power_efficiency      0.835     0.886  33.0
# walking_speed_kmh ↔ max_payload_kg     0.633     0.481  32.0
# company_age_years ↔ unit_cost_usd_k    0.658     0.430  23.0
# speed_ratio ↔ unit_cost_usd_k         -0.897     0.106  15.0

# %% [markdown]
# ### Answer
#
# 3 surprising correlations (robust under **both** Pearson r and Spearman ρ):
#
# | Correlation | r / ρ | Why it's surprising |
# |---|---|---|
# | payload ↔ power efficiency | +0.84 / +0.89 | heavier-rated robots are **more** efficient, not less |
# | walking speed ↔ payload | +0.63 / +0.48 | fast **and** strong together (no trade-off) |
# | company age ↔ cost | +0.66 / +0.43 | **older** firms build **pricier** robots |
#
# ⚠️ **Trap:** `speed_ratio ↔ cost` shows r = −0.90 but ρ = +0.11 → fake, driven by outliers. Always check Spearman against Pearson.

# %%
# Helper: percent difference "a is X% more/less than b"
def pct_more(a, b):
    return round((a / b - 1) * 100, 1)

llm   = df[df['llm_integrated'] == True]
nollm = df[df['llm_integrated'] == False]

# ---------- Discovery 1: does adding an LLM make a robot more expensive? ----------
print('D1  LLM vs non-LLM unit cost (usd_k)')
print('    mean  :', round(llm['unit_cost_usd_k'].mean(),1), 'vs', round(nollm['unit_cost_usd_k'].mean(),1),
      '->', pct_more(llm['unit_cost_usd_k'].mean(),  nollm['unit_cost_usd_k'].mean()), '%')
print('    median:', llm['unit_cost_usd_k'].median(), 'vs', nollm['unit_cost_usd_k'].median(),
      '->', pct_more(llm['unit_cost_usd_k'].median(), nollm['unit_cost_usd_k'].median()), '%')
print('    check - most expensive LLM robot:',
      llm.loc[llm['unit_cost_usd_k'].idxmax(), ['robot_name','unit_cost_usd_k']].tolist(),
      '| most expensive non-LLM:', nollm.loc[nollm['unit_cost_usd_k'].idxmax(), ['robot_name','unit_cost_usd_k']].tolist())

# ---------- Discovery 2: Europe = most ready, least innovative ----------
print('\nD2  Continent innovation vs readiness')
print(df.groupby('continent')[['innovation_score','commercial_readiness_idx']].mean().round(1))
e = df[df.continent=='Europe']; na = df[df.continent=='North America']
print('    Europe vs N.America: readiness', pct_more(e['commercial_readiness_idx'].mean(), na['commercial_readiness_idx'].mean()),
      '% | innovation', pct_more(e['innovation_score'].mean(), na['innovation_score'].mean()), '%')

# ---------- Discovery 3: wheeled robots cost more than (harder) bipeds ----------
bip = df[df.biped]; whl = df[~df.biped]
print('\nD3  Wheeled vs biped unit cost')
print('    mean  :', round(whl['unit_cost_usd_k'].mean(),1), 'vs', round(bip['unit_cost_usd_k'].mean(),1),
      '->', pct_more(whl['unit_cost_usd_k'].mean(), bip['unit_cost_usd_k'].mean()), '%')
print('    median:', whl['unit_cost_usd_k'].median(), 'vs', bip['unit_cost_usd_k'].median(),
      '->', pct_more(whl['unit_cost_usd_k'].median(), bip['unit_cost_usd_k'].median()), '%   <- gap shrinks!')
print('    check - cheapest wheeled robot:', whl.loc[whl['unit_cost_usd_k'].idxmin(), ['robot_name','unit_cost_usd_k']].tolist())
# Out:
# D1  LLM vs non-LLM unit cost (usd_k)
#     mean  : 60.0 vs 693.1 -> -91.3 %
#     median: 67.5 vs 150.0 -> -55.0 %
#     check - most expensive LLM robot: ['Unitree H1 Pro', np.float64(110.0)] | most expensive non-LLM: ['Archax', np.float64(3000.0)]
#
# D2  Continent innovation vs readiness
#                innovation_score  commercial_readiness_idx
# continent
# Asia                       46.6                      67.4
# Europe                     42.0                      84.2
# North America              57.8                      78.2
#     Europe vs N.America: readiness 7.7 % | innovation -27.3 %
#
# D3  Wheeled vs biped unit cost
#     mean  : 949.2 vs 379.2 -> 150.3 %
#     median: 72.5 vs 90.0 -> -19.4 %   <- gap shrinks!
#     check - cheapest wheeled robot: ['Pepper (2025)', np.float64(25.0)]

# %% [markdown]
# ### Findings
#
# **1. LLMs don't make robots expensive — the cheap ones have AI.**
# LLM robots are **55% cheaper** (median $67.5k vs $150k). Priciest LLM robot = Unitree H1 Pro ($110k); priciest non-LLM = Archax ($3,000k).
#
# **2. Europe: most market-ready, least innovative.**
# Europe leads readiness but is **−27% on innovation** vs North America. NA innovates most but isn't the most ready → an innovation-vs-maturity trade-off.
#
# **3. "Wheeled costs 150% more than legged" is an outlier mirage — it even reverses.**
# True by mean (+150%), but by **median wheeled is ~19% cheaper** ($72.5k vs $90k). Cheapest wheeled robot = Pepper ($25k). A few costly service/space units skew the mean.

# %%
# ---- THE TRAP: Japan's $1,388k average ----
jp = df[df.country == 'Japan']
print('Japan: 6 robots, but only', jp['unit_cost_usd_k'].notna().sum(), 'have a price.')
print(jp[['robot_name', 'unit_cost_usd_k', 'deployment_stage', 'outlier_flag']].to_string(index=False))
print('\nThe "average" =', round(jp['unit_cost_usd_k'].mean()), 'k  is built from just these 4 values:',
      sorted(jp['unit_cost_usd_k'].dropna().tolist()))

# ---- THE TRUTH, one layer at a time ----
print('\n--- peel back the trap ---')
# (a) tiny n + outliers: drop the flagged outlier (Archax) and the retired museum piece (Asimo)
real = jp[(~jp.outlier_flag) & (jp.deployment_stage != 'Retired')]['unit_cost_usd_k'].dropna()
print('(a) excl. Archax (outlier_flag) + Asimo (retired):', real.tolist(),
      '-> the only priced *current* Japanese humanoid is Pepper at $25k')

# (b) missing data: 7 countries have ZERO priced robots and silently vanish from the ranking
zero = [c for c in df.country.unique() if df[df.country == c]['unit_cost_usd_k'].notna().sum() == 0]
print('(b) countries with NO price data (dropped from the ranking entirely):', zero)

# (c) duplicates: rows that are the same robot recorded twice
dups = df[df.duplicated(['company', 'height_cm', 'weight_kg', 'dof'], keep=False)]
print('(c) duplicate rows (same company/height/weight/dof) — 2 of Japan\'s 4 prices are the SAME Pepper:')
print(dups[['robot_name', 'company', 'country', 'unit_cost_usd_k', 'units_deployed']].to_string(index=False))
# Out:
# Japan: 6 robots, but only 4 have a price.
#      robot_name  unit_cost_usd_k deployment_stage  outlier_flag
# Asimo (Retired)           2500.0          Retired         False
#          Hrp-5P              NaN         Research         False
#   Pepper (2025)             25.0     Discontinued         False
#           Hrp-4              NaN         Research         False
#          Pepper             25.0     Discontinued         False
#          Archax           3000.0       Commercial          True
#
# The "average" = 1388 k  is built from just these 4 values: [25.0, 25.0, 2500.0, 3000.0]
#
# --- peel back the trap ---
# (a) excl. Archax (outlier_flag) + Asimo (retired): [25.0, 25.0] -> the only priced *current* Japanese humanoid is Pepper at $25k
# (b) countries with NO price data (dropped from the ranking entirely): ['Canada', 'Norway', 'South Korea', 'Israel', 'Germany', 'UK', 'Iran']
# (c) duplicate rows (same company/height/weight/dof) — 2 of Japan's 4 prices are the SAME Pepper:
#          robot_name           company country  unit_cost_usd_k  units_deployed
#       Pepper (2025) Softbank Robotics   Japan             25.0          2000.0
#           Robot One   Enchanted Tools  France              NaN             5.0
#              Pepper Softbank Robotics   Japan             25.0          2000.0
# Enchanted Robot One   Enchanted Tools  France              NaN             5.0

# %% [markdown]
# ### The trap, and the truth next to it
#
# **Claim:** "Japan builds the most expensive robots — $1,388k on average."
#
# **Why it's a lie:** that average rests on **4 values: [25, 25, 2500, 3000]** ($k).
#
# | Failure mode | What's really going on |
# |---|---|
# | **Mean over a tiny n** | n=4 (Japan has 6 robots). Two huge numbers set the average: **Asimo $2,500k** (retired since 2022 — a museum piece) and **Archax $3,000k** (a rideable mech, and it's literally `outlier_flag = True`). |
# | **Held up by missing data** | 7 countries — **Canada, Norway, Germany, UK, Israel, South Korea, Iran** — have *zero* priced robots, so they silently drop out of the ranking. "Japan is #1" only among the handful that reported. |
# | **Duplicate rows as "different"** | 2 of Japan's 4 prices are the **same robot**: `Pepper` and `Pepper (2025)` are identical (121 cm, 29 kg, $25k, 2000 units). Same trap hits France: `Robot One` = `Enchanted Robot One`. So "52 robots" is really **50 unique**, and Pepper's deployment is double-counted (2000 + 2000). |
#
# **The truth:** strip the outlier and the retired piece, and the only priced *current* Japanese humanoid is **Pepper at $25k** — among the **cheapest** in the dataset, not the most expensive. The headline was exactly backwards.
#
# **Takeaway:** before trusting a group average, always ask three questions — *how many rows? what's missing? are any rows the same thing twice?*
